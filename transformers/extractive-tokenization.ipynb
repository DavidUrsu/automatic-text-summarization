# %% [markdown]
# # Extractive text summarization using transformers

# %%
text = """BENGALURU, April 25 (Reuters) - Apple (AAPL.O), opens new tab aims to make most of its iPhones sold in the United States at factories in India by the end of 2026, and is speeding up those plans to navigate potentially higher tariffs in China, its main manufacturing base, a source told Reuters.
The U.S. tech giant is holding urgent talks with contract manufacturers Foxconn (2317.TW), opens new tab and Tata to achieve that goal, the person, who declined to be named as the planning process is confidential, said on Friday.
Apple and Foxconn did not immediately respond to requests for comment, while Tata declined to comment.
Apple sells over 60 million iPhones in the U.S. annually with roughly 80% of them made in China currently.
Prime Minister Narendra Modi has in recent years promoted India as a smartphone manufacturing hub, but higher duties on importing mobile phone parts compared to many other countries means it is still expensive for companies to produce in India.
For iPhones, manufacturing costs in India are 5-8% higher than in China, with the difference rising to as much as 10% in some cases, the source said.
Apple has already stepped up production in India to beat U.S. President Donald Trump's tariffs, shipping some 600 tons of iPhones worth $2 billion to the United States in March. The shipments from India marked a record for both its contractors Tata and Foxconn, with the latter alone accounting for smartphones worth $1.3 billion, Reuters reported last week.
In April, the U.S. administration imposed 26% duties on imports from India, much lower than the more than 100% China was facing at the time. Washington has since paused most duties for three months, except for China.
Trump's administration has since signalled openness to de-escalating the trade war between the world's two largest economies that has raised fears of recession.
The Financial Times first reported about Apple's plan on Friday.
As Apple diversifies its manufacturing beyond China, it has positioned India for a critical role. Foxconn and Tata, its two main suppliers there, have three factories in all, with two more being built.
"""

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(text)

# %%
tokens = [token.text.lower() for token  in doc 
          if not token.is_stop and 
          not token.is_punct and 
          token.text != '\n']

# %%
tokens
# Out:
# ['bengaluru',
#  'april',
#  '25',
#  'reuters',
#  'apple',
#  'aapl.o',
#  'opens',
#  'new',
#  'tab',
#  'aims',
#  'iphones',
#  'sold',
#  'united',
#  'states',
#  'factories',
#  'india',
#  'end',
#  '2026',
#  'speeding',
#  'plans',
#  'navigate',
#  'potentially',
#  'higher',
#  'tariffs',
#  'china',
#  'main',
#  'manufacturing',
#  'base',
#  'source',
#  'told',
#  'reuters',
#  'u.s.',
#  'tech',
#  'giant',
#  'holding',
#  'urgent',
#  'talks',
#  'contract',
#  'manufacturers',
#  'foxconn',
#  '2317.tw',
#  'opens',
#  'new',
#  'tab',
#  'tata',
#  'achieve',
#  'goal',
#  'person',
#  'declined',
#  'named',
#  'planning',
#  'process',
#  'confidential',
#  'said',
#  'friday',
#  'apple',
#  'foxconn',
#  'immediately',
#  'respond',
#  'requests',
#  'comment',
#  'tata',
#  'declined',
#  'comment',
#  'apple',
#  'sells',
#  '60',
#  'million',
#  'iphones',
#  'u.s.',
#  'annually',
#  'roughly',
#  '80',
#  'china',
#  'currently',
#  'prime',
#  'minister',
#  'narendra',
#  'modi',
#  'recent',
#  'years',
#  'promoted',
#  'india',
#  'smartphone',
#  'manufacturing',
#  'hub',
#  'higher',
#  'duties',
#  'importing',
#  'mobile',
#  'phone',
#  'parts',
#  'compared',
#  'countries',
#  'means',
#  'expensive',
#  'companies',
#  'produce',
#  'india',
#  'iphones',
#  'manufacturing',
#  'costs',
#  'india',
#  '5',
#  '8',
#  'higher',
#  'china',
#  'difference',
#  'rising',
#  '10',
#  'cases',
#  'source',
#  'said',
#  'apple',
#  'stepped',
#  'production',
#  'india',
#  'beat',
#  'u.s.',
#  'president',
#  'donald',
#  'trump',
#  'tariffs',
#  'shipping',
#  '600',
#  'tons',
#  'iphones',
#  'worth',
#  '$',
#  '2',
#  'billion',
#  'united',
#  'states',
#  'march',
#  'shipments',
#  'india',
#  'marked',
#  'record',
#  'contractors',
#  'tata',
#  'foxconn',
#  'accounting',
#  'smartphones',
#  'worth',
#  '$',
#  '1.3',
#  'billion',
#  'reuters',
#  'reported',
#  'week',
#  'april',
#  'u.s.',
#  'administration',
#  'imposed',
#  '26',
#  'duties',
#  'imports',
#  'india',
#  'lower',
#  '100',
#  'china',
#  'facing',
#  'time',
#  'washington',
#  'paused',
#  'duties',
#  'months',
#  'china',
#  'trump',
#  'administration',
#  'signalled',
#  'openness',
#  'de',
#  'escalating',
#  'trade',
#  'war',
#  'world',
#  'largest',
#  'economies',
#  'raised',
#  'fears',
#  'recession',
#  'financial',
#  'times',
#  'reported',
#  'apple',
#  'plan',
#  'friday',
#  'apple',
#  'diversifies',
#  'manufacturing',
#  'china',
#  'positioned',
#  'india',
#  'critical',
#  'role',
#  'foxconn',
#  'tata',
#  'main',
#  'suppliers',
#  'factories',
#  'built']

# %%
tokens1 = []
stopwords = list(STOP_WORDS)
allowed_pos = ['PROPN', 'ADJ', 'NOUN', 'VERB']
for token in doc:
    if token.text in stopwords or token.text in punctuation:
        continue
    if token.pos_ in allowed_pos:
        tokens1.append(token.text)

# %%
tokens1
# Out:
# ['BENGALURU',
#  'April',
#  'Reuters',
#  'Apple',
#  'AAPL.O',
#  'opens',
#  'new',
#  'tab',
#  'aims',
#  'iPhones',
#  'sold',
#  'United',
#  'States',
#  'factories',
#  'India',
#  'end',
#  'speeding',
#  'plans',
#  'navigate',
#  'higher',
#  'tariffs',
#  'China',
#  'main',
#  'manufacturing',
#  'base',
#  'source',
#  'told',
#  'Reuters',
#  'U.S.',
#  'tech',
#  'giant',
#  'holding',
#  'urgent',
#  'talks',
#  'contract',
#  'manufacturers',
#  'Foxconn',
#  'opens',
#  'new',
#  'tab',
#  'Tata',
#  'achieve',
#  'goal',
#  'person',
#  'declined',
#  'named',
#  'planning',
#  'process',
#  'confidential',
#  'said',
#  'Friday',
#  'Apple',
#  'Foxconn',
#  'respond',
#  'requests',
#  'comment',
#  'Tata',
#  'declined',
#  'comment',
#  'Apple',
#  'sells',
#  'iPhones',
#  'U.S.',
#  'China',
#  'Prime',
#  'Minister',
#  'Narendra',
#  'Modi',
#  'recent',
#  'years',
#  'promoted',
#  'India',
#  'smartphone',
#  'manufacturing',
#  'hub',
#  'higher',
#  'duties',
#  'importing',
#  'mobile',
#  'phone',
#  'parts',
#  'compared',
#  'countries',
#  'means',
#  'expensive',
#  'companies',
#  'produce',
#  'India',
#  'iPhones',
#  'manufacturing',
#  'costs',
#  'India',
#  'higher',
#  'China',
#  'difference',
#  'rising',
#  'cases',
#  'source',
#  'said',
#  'Apple',
#  'stepped',
#  'production',
#  'India',
#  'beat',
#  'U.S.',
#  'President',
#  'Donald',
#  'Trump',
#  'tariffs',
#  'shipping',
#  'tons',
#  'iPhones',
#  'worth',
#  'United',
#  'States',
#  'March',
#  'shipments',
#  'India',
#  'marked',
#  'record',
#  'contractors',
#  'Tata',
#  'Foxconn',
#  'accounting',
#  'smartphones',
#  'worth',
#  'Reuters',
#  'reported',
#  'week',
#  'April',
#  'U.S.',
#  'administration',
#  'imposed',
#  'duties',
#  'imports',
#  'India',
#  'lower',
#  'China',
#  'facing',
#  'time',
#  'Washington',
#  'paused',
#  'duties',
#  'months',
#  'China',
#  'Trump',
#  'administration',
#  'signalled',
#  'openness',
#  'de',
#  'escalating',
#  'trade',
#  'war',
#  'world',
#  'largest',
#  'economies',
#  'raised',
#  'fears',
#  'recession',
#  'Financial',
#  'Times',
#  'reported',
#  'Apple',
#  'plan',
#  'Friday',
#  'Apple',
#  'diversifies',
#  'manufacturing',
#  'China',
#  'positioned',
#  'India',
#  'critical',
#  'role',
#  'Foxconn',
#  'Tata',
#  'main',
#  'suppliers',
#  'factories',
#  'built']

# %%
from collections import Counter

# %%
word_freq = Counter(tokens1)

# %%
word_freq
# Out:
# Counter({'India': 8,
#          'Apple': 6,
#          'China': 6,
#          'iPhones': 4,
#          'manufacturing': 4,
#          'U.S.': 4,
#          'Foxconn': 4,
#          'Tata': 4,
#          'Reuters': 3,
#          'higher': 3,
#          'duties': 3,
#          'April': 2,
#          'opens': 2,
#          'new': 2,
#          'tab': 2,
#          'United': 2,
#          'States': 2,
#          'factories': 2,
#          'tariffs': 2,
#          'main': 2,
#          'source': 2,
#          'declined': 2,
#          'said': 2,
#          'Friday': 2,
#          'comment': 2,
#          'Trump': 2,
#          'worth': 2,
#          'reported': 2,
#          'administration': 2,
#          'BENGALURU': 1,
#          'AAPL.O': 1,
#          'aims': 1,
#          'sold': 1,
#          'end': 1,
#          'speeding': 1,
#          'plans': 1,
#          'navigate': 1,
#          'base': 1,
#          'told': 1,
#          'tech': 1,
#          'giant': 1,
#          'holding': 1,
#          'urgent': 1,
#          'talks': 1,
#          'contract': 1,
#          'manufacturers': 1,
#          'achieve': 1,
#          'goal': 1,
#          'person': 1,
#          'named': 1,
#          'planning': 1,
#          'process': 1,
#          'confidential': 1,
#          'respond': 1,
#          'requests': 1,
#          'sells': 1,
#          'Prime': 1,
#          'Minister': 1,
#          'Narendra': 1,
#          'Modi': 1,
#          'recent': 1,
#          'years': 1,
#          'promoted': 1,
#          'smartphone': 1,
#          'hub': 1,
#          'importing': 1,
#          'mobile': 1,
#          'phone': 1,
#          'parts': 1,
#          'compared': 1,
#          'countries': 1,
#          'means': 1,
#          'expensive': 1,
#          'companies': 1,
#          'produce': 1,
#          'costs': 1,
#          'difference': 1,
#          'rising': 1,
#          'cases': 1,
#          'stepped': 1,
#          'production': 1,
#          'beat': 1,
#          'President': 1,
#          'Donald': 1,
#          'shipping': 1,
#          'tons': 1,
#          'March': 1,
#          'shipments': 1,
#          'marked': 1,
#          'record': 1,
#          'contractors': 1,
#          'accounting': 1,
#          'smartphones': 1,
#          'week': 1,
#          'imposed': 1,
#          'imports': 1,
#          'lower': 1,
#          'facing': 1,
#          'time': 1,
#          'Washington': 1,
#          'paused': 1,
#          'months': 1,
#          'signalled': 1,
#          'openness': 1,
#          'de': 1,
#          'escalating': 1,
#          'trade': 1,
#          'war': 1,
#          'world': 1,
#          'largest': 1,
#          'economies': 1,
#          'raised': 1,
#          'fears': 1,
#          'recession': 1,
#          'Financial': 1,
#          'Times': 1,
#          'plan': 1,
#          'diversifies': 1,
#          'positioned': 1,
#          'critical': 1,
#          'role': 1,
#          'suppliers': 1,
#          'built': 1})

# %%
max_freq = max(word_freq.values())

# %%
max_freq
# Out:
# 8

# %%
for word in word_freq.keys():
    word_freq[word] = (word_freq[word]/max_freq)

# %%
word_freq
# Out:
# Counter({'India': 1.0,
#          'Apple': 0.75,
#          'China': 0.75,
#          'iPhones': 0.5,
#          'manufacturing': 0.5,
#          'U.S.': 0.5,
#          'Foxconn': 0.5,
#          'Tata': 0.5,
#          'Reuters': 0.375,
#          'higher': 0.375,
#          'duties': 0.375,
#          'April': 0.25,
#          'opens': 0.25,
#          'new': 0.25,
#          'tab': 0.25,
#          'United': 0.25,
#          'States': 0.25,
#          'factories': 0.25,
#          'tariffs': 0.25,
#          'main': 0.25,
#          'source': 0.25,
#          'declined': 0.25,
#          'said': 0.25,
#          'Friday': 0.25,
#          'comment': 0.25,
#          'Trump': 0.25,
#          'worth': 0.25,
#          'reported': 0.25,
#          'administration': 0.25,
#          'BENGALURU': 0.125,
#          'AAPL.O': 0.125,
#          'aims': 0.125,
#          'sold': 0.125,
#          'end': 0.125,
#          'speeding': 0.125,
#          'plans': 0.125,
#          'navigate': 0.125,
#          'base': 0.125,
#          'told': 0.125,
#          'tech': 0.125,
#          'giant': 0.125,
#          'holding': 0.125,
#          'urgent': 0.125,
#          'talks': 0.125,
#          'contract': 0.125,
#          'manufacturers': 0.125,
#          'achieve': 0.125,
#          'goal': 0.125,
#          'person': 0.125,
#          'named': 0.125,
#          'planning': 0.125,
#          'process': 0.125,
#          'confidential': 0.125,
#          'respond': 0.125,
#          'requests': 0.125,
#          'sells': 0.125,
#          'Prime': 0.125,
#          'Minister': 0.125,
#          'Narendra': 0.125,
#          'Modi': 0.125,
#          'recent': 0.125,
#          'years': 0.125,
#          'promoted': 0.125,
#          'smartphone': 0.125,
#          'hub': 0.125,
#          'importing': 0.125,
#          'mobile': 0.125,
#          'phone': 0.125,
#          'parts': 0.125,
#          'compared': 0.125,
#          'countries': 0.125,
#          'means': 0.125,
#          'expensive': 0.125,
#          'companies': 0.125,
#          'produce': 0.125,
#          'costs': 0.125,
#          'difference': 0.125,
#          'rising': 0.125,
#          'cases': 0.125,
#          'stepped': 0.125,
#          'production': 0.125,
#          'beat': 0.125,
#          'President': 0.125,
#          'Donald': 0.125,
#          'shipping': 0.125,
#          'tons': 0.125,
#          'March': 0.125,
#          'shipments': 0.125,
#          'marked': 0.125,
#          'record': 0.125,
#          'contractors': 0.125,
#          'accounting': 0.125,
#          'smartphones': 0.125,
#          'week': 0.125,
#          'imposed': 0.125,
#          'imports': 0.125,
#          'lower': 0.125,
#          'facing': 0.125,
#          'time': 0.125,
#          'Washington': 0.125,
#          'paused': 0.125,
#          'months': 0.125,
#          'signalled': 0.125,
#          'openness': 0.125,
#          'de': 0.125,
#          'escalating': 0.125,
#          'trade': 0.125,
#          'war': 0.125,
#          'world': 0.125,
#          'largest': 0.125,
#          'economies': 0.125,
#          'raised': 0.125,
#          'fears': 0.125,
#          'recession': 0.125,
#          'Financial': 0.125,
#          'Times': 0.125,
#          'plan': 0.125,
#          'diversifies': 0.125,
#          'positioned': 0.125,
#          'critical': 0.125,
#          'role': 0.125,
#          'suppliers': 0.125,
#          'built': 0.125})

# %%
# sentance tokenization
sent_token = [sent.text for sent in doc.sents]

# %%
sent_token
# Out:
# ['BENGALURU, April 25 (Reuters) - Apple (AAPL.O), opens new tab aims to make most of its iPhones sold in the United States at factories in India by the end of 2026, and is speeding up those plans to navigate potentially higher tariffs in China, its main manufacturing base, a source told Reuters.\n',
#  'The U.S. tech giant is holding urgent talks with contract manufacturers Foxconn (2317.TW), opens new tab and Tata to achieve that goal, the person, who declined to be named as the planning process is confidential, said on Friday.\n',
#  'Apple and Foxconn did not immediately respond to requests for comment, while Tata declined to comment.\n',
#  'Apple sells over 60 million iPhones in the U.S. annually with roughly 80% of them made in China currently.\n',
#  'Prime Minister Narendra Modi has in recent years promoted India as a smartphone manufacturing hub, but higher duties on importing mobile phone parts compared to many other countries means it is still expensive for companies to produce in India.\n',
#  'For iPhones, manufacturing costs in India are 5-8% higher than in China, with the difference rising to as much as 10% in some cases, the source said.\n',
#  "Apple has already stepped up production in India to beat U.S. President Donald Trump's tariffs, shipping some 600 tons of iPhones worth $2 billion to the United States in March.",
#  'The shipments from India marked a record for both its contractors Tata and Foxconn, with the latter alone accounting for smartphones worth $1.3 billion, Reuters reported last week.\n',
#  'In April, the U.S. administration imposed 26% duties on imports from India, much lower than the more than 100% China was facing at the time.',
#  'Washington has since paused most duties for three months, except for China.\n',
#  "Trump's administration has since signalled openness to de-escalating the trade war between the world's two largest economies that has raised fears of recession.\n",
#  "The Financial Times first reported about Apple's plan on Friday.\n",
#  'As Apple diversifies its manufacturing beyond China, it has positioned India for a critical role.',
#  'Foxconn and Tata, its two main suppliers there, have three factories in all, with two more being built.\n']

# %%
sent_score = {}
for sent in sent_token:
    for word in sent.split():
        if word.lower() in word_freq.keys():
            if sent not in sent_score.keys():
                sent_score[sent] = word_freq[word.lower()]
            else:
                sent_score[sent] += word_freq[word.lower()]
        print(word)
# Out:
# BENGALURU,
# April
# 25
# (Reuters)
# -
# Apple
# (AAPL.O),
# opens
# new
# tab
# aims
# to
# make
# most
# of
# its
# iPhones
# sold
# in
# the
# United
# States
# at
# factories
# in
# India
# by
# the
# end
# of
# 2026,
# and
# is
# speeding
# up
# those
# plans
# to
# navigate
# potentially
# higher
# tariffs
# in
# China,
# its
# main
# manufacturing
# base,
# a
# source
# told
# Reuters.
# The
# U.S.
# tech
# giant
# is
# holding
# urgent
# talks
# with
# contract
# manufacturers
# Foxconn
# (2317.TW),
# opens
# new
# tab
# and
# Tata
# to
# achieve
# that
# goal,
# the
# person,
# who
# declined
# to
# be
# named
# as
# the
# planning
# process
# is
# confidential,
# said
# on
# Friday.
# Apple
# and
# Foxconn
# did
# not
# immediately
# respond
# to
# requests
# for
# comment,
# while
# Tata
# declined
# to
# comment.
# Apple
# sells
# over
# 60
# million
# iPhones
# in
# the
# U.S.
# annually
# with
# roughly
# 80%
# of
# them
# made
# in
# China
# currently.
# Prime
# Minister
# Narendra
# Modi
# has
# in
# recent
# years
# promoted
# India
# as
# a
# smartphone
# manufacturing
# hub,
# but
# higher
# duties
# on
# importing
# mobile
# phone
# parts
# compared
# to
# many
# other
# countries
# means
# it
# is
# still
# expensive
# for
# companies
# to
# produce
# in
# India.
# For
# iPhones,
# manufacturing
# costs
# in
# India
# are
# 5-8%
# higher
# than
# in
# China,
# with
# the
# difference
# rising
# to
# as
# much
# as
# 10%
# in
# some
# cases,
# the
# source
# said.
# Apple
# has
# already
# stepped
# up
# production
# in
# India
# to
# beat
# U.S.
# President
# Donald
# Trump's
# tariffs,
# shipping
# some
# 600
# tons
# of
# iPhones
# worth
# $2
# billion
# to
# the
# United
# States
# in
# March.
# The
# shipments
# from
# India
# marked
# a
# record
# for
# both
# its
# contractors
# Tata
# and
# Foxconn,
# with
# the
# latter
# alone
# accounting
# for
# smartphones
# worth
# $1.3
# billion,
# Reuters
# reported
# last
# week.
# In
# April,
# the
# U.S.
# administration
# imposed
# 26%
# duties
# on
# imports
# from
# India,
# much
# lower
# than
# the
# more
# than
# 100%
# China
# was
# facing
# at
# the
# time.
# Washington
# has
# since
# paused
# most
# duties
# for
# three
# months,
# except
# for
# China.
# Trump's
# administration
# has
# since
# signalled
# openness
# to
# de-escalating
# the
# trade
# war
# between
# the
# world's
# two
# largest
# economies
# that
# has
# raised
# fears
# of
# recession.
# The
# Financial
# Times
# first
# reported
# about
# Apple's
# plan
# on
# Friday.
# As
# Apple
# diversifies
# its
# manufacturing
# beyond
# China,
# it
# has
# positioned
# India
# for
# a
# critical
# role.
# Foxconn
# and
# Tata,
# its
# two
# main
# suppliers
# there,
# have
# three
# factories
# in
# all,
# with
# two
# more
# being
# built.

# %%
sent_score
# Out:
# {'BENGALURU, April 25 (Reuters) - Apple (AAPL.O), opens new tab aims to make most of its iPhones sold in the United States at factories in India by the end of 2026, and is speeding up those plans to navigate potentially higher tariffs in China, its main manufacturing base, a source told Reuters.\n': 3.5,
#  'The U.S. tech giant is holding urgent talks with contract manufacturers Foxconn (2317.TW), opens new tab and Tata to achieve that goal, the person, who declined to be named as the planning process is confidential, said on Friday.\n': 2.625,
#  'Apple and Foxconn did not immediately respond to requests for comment, while Tata declined to comment.\n': 0.5,
#  'Apple sells over 60 million iPhones in the U.S. annually with roughly 80% of them made in China currently.\n': 0.125,
#  'Prime Minister Narendra Modi has in recent years promoted India as a smartphone manufacturing hub, but higher duties on importing mobile phone parts compared to many other countries means it is still expensive for companies to produce in India.\n': 3.0,
#  'For iPhones, manufacturing costs in India are 5-8% higher than in China, with the difference rising to as much as 10% in some cases, the source said.\n': 1.5,
#  "Apple has already stepped up production in India to beat U.S. President Donald Trump's tariffs, shipping some 600 tons of iPhones worth $2 billion to the United States in March.": 0.875,
#  'The shipments from India marked a record for both its contractors Tata and Foxconn, with the latter alone accounting for smartphones worth $1.3 billion, Reuters reported last week.\n': 1.25,
#  'In April, the U.S. administration imposed 26% duties on imports from India, much lower than the more than 100% China was facing at the time.': 1.125,
#  'Washington has since paused most duties for three months, except for China.\n': 0.5,
#  "Trump's administration has since signalled openness to de-escalating the trade war between the world's two largest economies that has raised fears of recession.\n": 1.25,
#  "The Financial Times first reported about Apple's plan on Friday.\n": 0.375,
#  'As Apple diversifies its manufacturing beyond China, it has positioned India for a critical role.': 0.875,
#  'Foxconn and Tata, its two main suppliers there, have three factories in all, with two more being built.\n': 0.625}

# %%
import pandas as pd

# %%
pd.DataFrame(sent_score.items(), columns=['Sentence', 'Score'])
# Out:
#                                              Sentence  Score
# 0   BENGALURU, April 25 (Reuters) - Apple (AAPL.O)...  3.500
# 1   The U.S. tech giant is holding urgent talks wi...  2.625
# 2   Apple and Foxconn did not immediately respond ...  0.500
# 3   Apple sells over 60 million iPhones in the U.S...  0.125
# 4   Prime Minister Narendra Modi has in recent yea...  3.000
# 5   For iPhones, manufacturing costs in India are ...  1.500
# 6   Apple has already stepped up production in Ind...  0.875
# 7   The shipments from India marked a record for b...  1.250
# 8   In April, the U.S. administration imposed 26% ...  1.125
# 9   Washington has since paused most duties for th...  0.500
# 10  Trump's administration has since signalled ope...  1.250
# 11  The Financial Times first reported about Apple...  0.375
# 12  As Apple diversifies its manufacturing beyond ...  0.875
# 13  Foxconn and Tata, its two main suppliers there...  0.625

# %%
from heapq import nlargest

# %%
num_sentences = 3
n = nlargest(num_sentences, sent_score, key=sent_score.get)

# %%
" ".join(n)
# Out:
# 'BENGALURU, April 25 (Reuters) - Apple (AAPL.O), opens new tab aims to make most of its iPhones sold in the United States at factories in India by the end of 2026, and is speeding up those plans to navigate potentially higher tariffs in China, its main manufacturing base, a source told Reuters.\n Prime Minister Narendra Modi has in recent years promoted India as a smartphone manufacturing hub, but higher duties on importing mobile phone parts compared to many other countries means it is still expensive for companies to produce in India.\n The U.S. tech giant is holding urgent talks with contract manufacturers Foxconn (2317.TW), opens new tab and Tata to achieve that goal, the person, who declined to be named as the planning process is confidential, said on Friday.\n'
